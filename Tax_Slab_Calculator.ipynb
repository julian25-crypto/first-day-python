# %% [markdown]
# <a href="https://colab.research.google.com/github/julian25-crypto/first-day-python/blob/main/Tax_Slab_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tax Slab Calculator

# Taking input
income = int(input("Enter your annual income: "))

tax = 0

# Calculating tax based on slabs
if income <= 250000:
    tax = 0
elif income <= 500000:
    tax = (income - 250000) * 0.05
elif income <= 1000000:
    tax = (250000 * 0.05) + (income - 500000) * 0.20
else:
    tax = (250000 * 0.05) + (500000 * 0.20) + (income - 1000000) * 0.30

net_income = income - tax

print("Tax Calculation ")
print("Annual Income:", income)
print("Total Tax Payable:", round(tax, 2))
print("Net Income After Tax:", round(net_income, 2))
# Out:
# Enter your annual income: 100000
# Tax Calculation
# Annual Income: 100000
# Total Tax Payable: 0
# Net Income After Tax: 100000
