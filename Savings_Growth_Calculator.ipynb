# %% [markdown]
# <a href="https://colab.research.google.com/github/julian25-crypto/first-day-python/blob/main/Savings_Growth_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Savings Growth Calculator

# Taking input from user
monthly_savings = int(input("Enter monthly savings amount: "))
months = int(input("Enter number of months: "))

# Calculating total savings
total_savings = monthly_savings * months

print(" Savings Summary")
print("Monthly Savings:", monthly_savings)
print("Number of Months:", months)
print("Total Accumulated Savings:", total_savings)
# Out:
# Enter monthly savings amount: 1000
# Enter number of months: 12
#  Savings Summary
# Monthly Savings: 1000
# Number of Months: 12
# Total Accumulated Savings: 12000
