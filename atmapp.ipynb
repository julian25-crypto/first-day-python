# %%
card_inserted = True
pin_correct = True
balance = int(input("how much you want to invest"))
print("current balance" , balance)
withdraw = True

if card_inserted:
  print("Card detected")
  if pin_correct :
    print("access granted")
    print("your balance is " , balance)

    if withdraw:
      withdraw_amt = int(input("how much you want to withdraw"))
      print("the guy wants to withdraw = " , withdraw_amt)
      if withdraw >= balance:
        balance = balance - withdraw_amt
        print("Current balance = " , balance)
      else:
        print("You dont have enough balance")
    else:
      print("the guy does not want to withdraw")
  else:
    print("wrong password")
else:
  print("Insert the card")
# Out:
# how much you want to invest6000
# current balance 6000
# Card detected
# access granted
# your balance is  6000
# how much you want to withdraw7000
# the guy wants to withdraw =  7000
# You dont have enough balance
