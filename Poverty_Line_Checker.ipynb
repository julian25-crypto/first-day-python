# %% [markdown]
# <a href="https://colab.research.google.com/github/julian25-crypto/first-day-python/blob/main/Poverty_Line_Checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Poverty Line Checker

# Taking inputs
poverty_line = float(input("Enter poverty line income: "))
household_income = float(input("Enter household income: "))

# Checking condition
if household_income < poverty_line:
    print("The household is Below Poverty Line (BPL).")
else:
    print("The household is Above Poverty Line (APL).")
# Out:
# Enter poverty line income: 50000
# Enter household income: 30000
# The household is Below Poverty Line (BPL).
