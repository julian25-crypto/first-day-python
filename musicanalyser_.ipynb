# %% [markdown]
# <a href="https://colab.research.google.com/github/julian25-crypto/first-day-python/blob/main/musicanalyser_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SETS
#
# only when we want unique elements

# %%
names = ["yash" , "kirti" , "kunal" , "yash" , "yash"]
print(names)
# Out:
# ['yash', 'kirti', 'kunal', 'yash', 'yash']

# %%
roll_numbers = { 101 , 102 , 108 , 105 , 106}
print(roll_numbers)
print(type(roll_numbers))
# Out:
# {101, 102, 105, 106, 108}
# <class 'set'>

# %%
#set of cities
cities = {"pune" , "delhi" , "bangalore"}
print(cities)
# Out:
# {'bangalore', 'delhi', 'pune'}

# %%
cities.remove("pune")
print(cities)
# Out:
# {'bangalore', 'delhi'}

# %%
cities.add("mumbai")
print(cities)
# Out:
# {'bangalore', 'mumbai', 'delhi'}

# %% [markdown]
# music genre analyser

# %%
friend1 = { "hip-hop" , "retro" , "pop" , "country"}
friend2 = { "edm" , "bollywood" , "pop" , "jazz"}
print(friend1)
print(friend2)
# Out:
# {'retro', 'hip-hop', 'pop', 'country'}
# {'jazz', 'pop', 'edm', 'bollywood'}

# %%
print(friend1 | friend2)
# Out:
# {'pop', 'edm', 'bollywood', 'retro', 'country', 'hip-hop', 'jazz'}

# %%
print(friend1 & friend2)
# Out:
# {'pop'}
